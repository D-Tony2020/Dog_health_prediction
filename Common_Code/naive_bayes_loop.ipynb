# %%
import os
import numpy as np
import pandas as pd
import joblib
from functools import reduce
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler
import csv

from imblearn.over_sampling import RandomOverSampler

from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, StratifiedKFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.multiclass import OneVsRestClassifier
#from skmultilearn.model_selection import MultiLabelStratifiedKFold
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
# breed
feat_breed = pd.read_pickle('../features/breed.pkl')
feat_breed_v2 = pd.read_pickle('../features/breed_v2.pkl')

feat_breed_top50 = pd.read_pickle('../features/breed_top50.pkl')
feat_breed_top50_v2 = pd.read_pickle('../features/breed_top50_v2.pkl')

feat_breed_group = pd.read_pickle('../features/breed_group.pkl')
feat_sub_breed = pd.read_pickle('../features/sub_breed.pkl')
feat_breed_type = pd.read_pickle('../features/breed_type.pkl')

feat_breed_pure_or_mix = pd.read_pickle('../features/breed_pure_or_mix.pkl')

# age
feat_age = pd.read_csv('../features/age_with_id.csv')

# sex
feat_sex = pd.read_csv('../features/one_hot_encoded_sex_with_id.csv')

# Climate
# feat_HotWheater = pd.read_csv('../features/one_hot_encoded_HotWheater_with_id.csv')
# feat_ModerateWheather = pd.read_csv('../features/one_hot_encoded_ModerateWheather_with_id.csv')
# feat_ColdWheater_with_id = pd.read_csv('../features/one_hot_encoded_ColdWheater_with_id.csv')
feat_cold_month = pd.read_pickle('../features/ColdMonths.pkl')
feat_hot_month = pd.read_pickle('../features/HotMonths.pkl')

# Diet
feat_diet = pd.read_pickle('../features/diet.pkl')

# Physical Activity
feat_pa_total_hours = pd.read_csv('../features/PhysicalActivity_total_hours.csv')
feat_pa_surface = pd.read_csv('../features/PhysicalActivity_surface.csv')
feat_pa_wheather = pd.read_csv('../features/PhysicalActivity_wheather.csv')

# Owner Demographics
feat_od_income = pd.read_pickle('../features/od_income.pkl')

# Residentual
feat_prim_census_division = pd.read_pickle('../features/primary_residence_census_division.pkl')

# disease
#feat_disease_input = pd.read_csv('../features/one_hot_encoded_disease_input.csv')
feat_disease_output_binary = pd.read_csv('../features/disease_output_binary.csv')
feat_disease_output = pd.read_csv('../features/disease_output.csv')

# age_condition
feat_age_condition = pd.read_pickle('../features/age_condition.pkl')
feat_age_condition_type = pd.read_pickle('../features/age_condition_type.pkl')


features_list = [

    # breed
    #feat_breed,
    #feat_breed_v2,
    #feat_breed_top50,
    feat_breed_top50_v2,
    feat_breed_group,
    feat_sub_breed,
    feat_breed_type,
    feat_breed_pure_or_mix,

    # age
    feat_age,   # 24881 dog_ids

    # sex
    feat_sex,

    # diet
    feat_diet,  # 33141 dog_ids for df_diet_consistency

    # Old climate
    #feat_HotWheater,
    #feat_ModerateWheather,
    #feat_ColdWheater_with_id,

    # Climate
    feat_hot_month,
    feat_cold_month,

    # Physical Activity
    feat_pa_surface,
    feat_pa_total_hours,
    feat_pa_wheather,   # 26406 dog_ids

    # owner demographic
    feat_od_income,    # 29096 dog_ids

    # Residentual
    feat_prim_census_division,

    # disease
    #feat_disease_input,
    #feat_disease_output_binary,
    #feat_disease_output
]

# %%
len(features_list)
# Out:
# 15

# %%
# Merge the two dataframes based on dog_id
#data = pd.merge(features_breed_group_v2, features_breed_top50_v2, on='dog_id')

# Initialize a list to store overall average AUC scores
overall_auc_results = []

for i, features in enumerate(features_list):
    # List of DataFrames to be merged
    list_input_features = [features_list[i]]  # Add more DataFrames as needed

    feature_names = [var_name for var_name, var_value in locals().items() if var_value is features and var_name.startswith('feat_')]
    print(feature_names)

    # Merge DataFrames iteratively using reduce
    input_features = reduce(lambda left, right: pd.merge(left, right, on='dog_id'), list_input_features)

    # Merge the two dataframes based on dog_id
    #data = pd.merge(feat_breed_top50_v2, feat_breed_group, on='dog_id')

    # Merge with disease output feature
    data = pd.merge(input_features, feat_disease_output_binary, on='dog_id')

    # Normalize the specified features in one line and save in the same columns
    features_to_normalize = ['age_diagnosis_years', 'df_diet_consistency', 'df_feedings_per_day', 'total_active_hours_y', 'pa_hot_weather_months_per_year', 'pa_cold_weather_months_per_year', 'total_active_hours_y', 'od_annual_income_range_usd']

    # select features that are in data
    features_to_normalize_in_data = [feature for feature in features_to_normalize if feature in data.columns]

    # Initialize MinMaxScaler
    scaler = MinMaxScaler()

    # Normalize
    if features_to_normalize_in_data:
        data[features_to_normalize_in_data] = scaler.fit_transform(data[features_to_normalize_in_data])
        #print(data[features_to_normalize_in_data])


    # Separate features and labels
    X = data.drop(['dog_id'] + ['hs_health_conditions_' + condition for condition in [
        'eye', 'ear', 'oral', 'skin', 'cardiac', 'respiratory', 'gastrointestinal',
        'liver', 'kidney', 'reproductive', 'orthopedic', 'neurological', 'endocrine',
        'hematologic', 'immune', 'infectious_disease', 'toxin_consumption', 'trauma', 'cancer'
    ]], axis=1)

    y_columns = ['hs_health_conditions_' + condition for condition in [
        'eye', 'ear', 'oral', 'skin', 'cardiac', 'respiratory', 'gastrointestinal',
        'liver', 'kidney', 'reproductive', 'orthopedic', 'neurological', 'endocrine',
        'hematologic', 'immune', 'infectious_disease', 'toxin_consumption', 'trauma', 'cancer'
    ]]
    y = data[y_columns]

    # Convert y to a binary format
    y_binary = (y == 1)

    # Initialize the Naive Bayes model
    nb_model = MultinomialNB()

    # Wrap the model with OneVsRestClassifier
    ovr_classifier = OneVsRestClassifier(nb_model)

    # Initialize MultilabelStratifiedKFold
    n_splits = 5  # You can adjust the number of splits as needed
    ml_stratified_kfold = MultilabelStratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    # Lists to store AUC scores and sample counts
    auc_scores_per_condition = {condition: [] for condition in y_columns}
    sample_counts_per_condition = {condition: [] for condition in y_columns}

    # Lists to store AUC scores and sample counts per fold
    auc_scores_per_fold = {f'Fold_{i+1}': [] for i in range(n_splits)}

    # Iterate through the splits
    for fold, (train_index, val_index) in enumerate(ml_stratified_kfold.split(X, y_binary)):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        #print('X_train: ', X_train.shape, '  X_val:', X_val.shape)
        y_train, y_val = y_binary.iloc[train_index], y_binary.iloc[val_index]

        # Train the model
        ovr_classifier.fit(X_train, y_train)

        # Make predictions on the validation set
        y_pred_proba = ovr_classifier.predict_proba(X_val)

        # Calculate the AUC score for each disease
        auc_scores = [roc_auc_score(y_val[column], y_pred_proba[:, i]) for i, column in enumerate(y_val.columns)]

        # Append AUC scores and sample counts to lists
        #all_auc_scores.extend(auc_scores)
        #for i, condition in enumerate(y_columns):
        #    auc_scores_per_condition[condition].append(auc_scores)

        # Calculate the AUC score for each fold
        fold_auc = roc_auc_score(y_val.values.ravel(), y_pred_proba.ravel())

        auc_scores_per_fold[f'Fold_{fold+1}'].append(fold_auc)

        for i, condition in enumerate(y_columns):
            sample_count = y_val[condition].sum()  # Count of positive samples for the condition
            sample_counts_per_condition[condition].append(sample_count)

        #print(f"\nFold {fold+1} AUC Scores for Diseases:")
        for i, auc_score in enumerate(auc_scores, start=1):
            #print(f"{y_val.columns[i-1]}: {auc_score}")
            auc_scores_per_condition[y_val.columns[i-1]].append(auc_score)


    average_auc_per_condition = {
        condition: sum(auc_scores) / len(auc_scores) for condition, auc_scores in auc_scores_per_condition.items()
    }
    # Calculate overall average AUC weighted by the number of samples
    overall_average_auc_sum = 0
    for auc_scores, sample_counts in zip(auc_scores_per_condition.values(), sample_counts_per_condition.values()):
        weighted_sum = sum(auc * sample_count for auc, sample_count in zip(auc_scores, sample_counts))
        overall_average_auc_sum += weighted_sum / sum(sample_counts)

    overall_average_auc = overall_average_auc_sum / len(auc_scores_per_condition)  # divide by the number of conditions
    # Average AUC-score per condition
    print("\n Average AUC Score per condition:")
    for condition, avg_auc in average_auc_per_condition.items():
        print(f"{condition}: {avg_auc}")

    # Print average AUC scores per fold
    print("\nAverage AUC Scores per Fold:")
    for fold, avg_auc in auc_scores_per_fold.items():
        print(f"Fold {fold}: {avg_auc}")

    # Get average AUC values as a list
    average_auc_list = list(average_auc_per_condition.values())

    # Calculate standard deviation of average AUC values
    overall_auc_std = np.std(average_auc_list)

    # Print average AUC scores
    print("\nWeighted Average AUC Score:")
    #print(f"Overall: {overall_average_auc}")
    print(f"{overall_average_auc * 100:.2f}%")
    print('===============================================\n')

    # Append the overall average AUC score and corresponding feature names to the list
    overall_auc_results.append({
        'Features': ', '.join(feature_names),
        'Overall Average AUC': overall_average_auc * 100
    })


# Save the overall average AUC scores and corresponding feature names to a CSV file
output_file_path = 'overall_average_auc_results.csv'
with open(output_file_path, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['Features', 'Overall Average AUC'])
    writer.writeheader()
    writer.writerows(overall_auc_results)

print(f"\nOverall Average AUC Scores saved to {output_file_path}")
# Out:
# ['feat_breed_top50_v2']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5814961589996709
# hs_health_conditions_ear: 0.5853358463288293
# hs_health_conditions_oral: 0.6418923034427354
# hs_health_conditions_skin: 0.5537811674440208
# hs_health_conditions_cardiac: 0.6664620336965638
# hs_health_conditions_respiratory: 0.6418506351191955
# hs_health_conditions_gastrointestinal: 0.5404492005672783
# hs_health_conditions_liver: 0.6142479880182784
# hs_health_conditions_kidney: 0.5491285602606133
# hs_health_conditions_reproductive: 0.5820749299525023
# hs_health_conditions_orthopedic: 0.5577331811022267
# hs_health_conditions_neurological: 0.5238306634290589
# hs_health_conditions_endocrine: 0.5473806512970738
# hs_health_conditions_hematologic: 0.5366997249989633
# hs_health_conditions_immune: 0.5526231780763766
# hs_health_conditions_infectious_disease: 0.5599102968931806
# hs_health_conditions_toxin_consumption: 0.5453007096162648
# hs_health_conditions_trauma: 0.5825737840494739
# hs_health_conditions_cancer: 0.5834933232346027
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7694995000271404]
# Fold Fold_2: [0.7687131317183395]
# Fold Fold_3: [0.7685675268978854]
# Fold Fold_4: [0.7700051613357275]
# Fold Fold_5: [0.7693702055641052]
#
# Weighted Average AUC Score:
# 57.61%
# ===============================================
#
# ['feat_breed_group']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5640226393805141
# hs_health_conditions_ear: 0.5795306808446916
# hs_health_conditions_oral: 0.635580609531547
# hs_health_conditions_skin: 0.5423706567336699
# hs_health_conditions_cardiac: 0.6375763349853306
# hs_health_conditions_respiratory: 0.6037381168198546
# hs_health_conditions_gastrointestinal: 0.5251339219942599
# hs_health_conditions_liver: 0.6055527391226093
# hs_health_conditions_kidney: 0.5485867903071953
# hs_health_conditions_reproductive: 0.5886178662590998
# hs_health_conditions_orthopedic: 0.5415798972752051
# hs_health_conditions_neurological: 0.5196334051880732
# hs_health_conditions_endocrine: 0.5427594709611705
# hs_health_conditions_hematologic: 0.49913221107501327
# hs_health_conditions_immune: 0.5303358367364436
# hs_health_conditions_infectious_disease: 0.5574247373162351
# hs_health_conditions_toxin_consumption: 0.5369599381552043
# hs_health_conditions_trauma: 0.5605187088568876
# hs_health_conditions_cancer: 0.5648607246705091
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7674022816385977]
# Fold Fold_2: [0.7672458248798196]
# Fold Fold_3: [0.7679223217766245]
# Fold Fold_4: [0.7678735379708223]
# Fold Fold_5: [0.7671595331226853]
#
# Weighted Average AUC Score:
# 56.23%
# ===============================================
#
# ['feat_sub_breed']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5701773217710312
# hs_health_conditions_ear: 0.578055304802754
# hs_health_conditions_oral: 0.639894860964769
# hs_health_conditions_skin: 0.5436194197622229
# hs_health_conditions_cardiac: 0.653740232869177
# hs_health_conditions_respiratory: 0.6093497828364157
# hs_health_conditions_gastrointestinal: 0.5280816095263032
# hs_health_conditions_liver: 0.6107127515731413
# hs_health_conditions_kidney: 0.5462745799373951
# hs_health_conditions_reproductive: 0.5997574969632301
# hs_health_conditions_orthopedic: 0.5403500627771812
# hs_health_conditions_neurological: 0.5179662243050719
# hs_health_conditions_endocrine: 0.54061926196527
# hs_health_conditions_hematologic: 0.49187743356533564
# hs_health_conditions_immune: 0.5498885308517729
# hs_health_conditions_infectious_disease: 0.5590739690091252
# hs_health_conditions_toxin_consumption: 0.5457066407150709
# hs_health_conditions_trauma: 0.5789775468159286
# hs_health_conditions_cancer: 0.5785987387614633
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7683515120903042]
# Fold Fold_2: [0.7678873405285827]
# Fold Fold_3: [0.7689660309215132]
# Fold Fold_4: [0.7689143520721232]
# Fold Fold_5: [0.7684066761069892]
#
# Weighted Average AUC Score:
# 56.75%
# ===============================================
#
# ['feat_breed_type']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5437847227800523
# hs_health_conditions_ear: 0.5630644383538845
# hs_health_conditions_oral: 0.6248835164958727
# hs_health_conditions_skin: 0.5319948340477831
# hs_health_conditions_cardiac: 0.6273198571776806
# hs_health_conditions_respiratory: 0.5774799681469208
# hs_health_conditions_gastrointestinal: 0.5204684051997017
# hs_health_conditions_liver: 0.603365242100258
# hs_health_conditions_kidney: 0.5316172575090682
# hs_health_conditions_reproductive: 0.5677815205699496
# hs_health_conditions_orthopedic: 0.5210157272602276
# hs_health_conditions_neurological: 0.5281848018517068
# hs_health_conditions_endocrine: 0.5391573796528994
# hs_health_conditions_hematologic: 0.4792929863319856
# hs_health_conditions_immune: 0.5338272316405288
# hs_health_conditions_infectious_disease: 0.5469908981981371
# hs_health_conditions_toxin_consumption: 0.5306853954629548
# hs_health_conditions_trauma: 0.5555114736815453
# hs_health_conditions_cancer: 0.5628995381117295
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7662965748981239]
# Fold Fold_2: [0.7652409410052907]
# Fold Fold_3: [0.765587209560908]
# Fold Fold_4: [0.7659602720545005]
# Fold Fold_5: [0.7658420275009097]
#
# Weighted Average AUC Score:
# 55.20%
# ===============================================
#
# ['feat_breed_pure_or_mix']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5
# hs_health_conditions_ear: 0.5
# hs_health_conditions_oral: 0.5
# hs_health_conditions_skin: 0.5
# hs_health_conditions_cardiac: 0.5
# hs_health_conditions_respiratory: 0.5
# hs_health_conditions_gastrointestinal: 0.5
# hs_health_conditions_liver: 0.5
# hs_health_conditions_kidney: 0.5
# hs_health_conditions_reproductive: 0.5
# hs_health_conditions_orthopedic: 0.5
# hs_health_conditions_neurological: 0.5
# hs_health_conditions_endocrine: 0.5
# hs_health_conditions_hematologic: 0.5
# hs_health_conditions_immune: 0.5
# hs_health_conditions_infectious_disease: 0.5
# hs_health_conditions_toxin_consumption: 0.5
# hs_health_conditions_trauma: 0.5
# hs_health_conditions_cancer: 0.5
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7570548807153147]
# Fold Fold_2: [0.7570324520054494]
# Fold Fold_3: [0.7572107168325705]
# Fold Fold_4: [0.757082392623168]
# Fold Fold_5: [0.7569978282884828]
#
# Weighted Average AUC Score:
# 50.00%
# ===============================================
#
# ['feat_age']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5
# hs_health_conditions_ear: 0.5
# hs_health_conditions_oral: 0.5
# hs_health_conditions_skin: 0.5
# hs_health_conditions_cardiac: 0.5
# hs_health_conditions_respiratory: 0.5
# hs_health_conditions_gastrointestinal: 0.5
# hs_health_conditions_liver: 0.5
# hs_health_conditions_kidney: 0.5
# hs_health_conditions_reproductive: 0.5
# hs_health_conditions_orthopedic: 0.5
# hs_health_conditions_neurological: 0.5
# hs_health_conditions_endocrine: 0.5
# hs_health_conditions_hematologic: 0.5
# hs_health_conditions_immune: 0.5
# hs_health_conditions_infectious_disease: 0.5
# hs_health_conditions_toxin_consumption: 0.5
# hs_health_conditions_trauma: 0.5
# hs_health_conditions_cancer: 0.5
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7538657827026516]
# Fold Fold_2: [0.7539884116607563]
# Fold Fold_3: [0.7538812573736124]
# Fold Fold_4: [0.7540623235815609]
# Fold Fold_5: [0.7540292535888202]
#
# Weighted Average AUC Score:
# 50.00%
# ===============================================
#
# ['feat_sex']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5119674596714547
# hs_health_conditions_ear: 0.5148650660157965
# hs_health_conditions_oral: 0.4989513270571603
# hs_health_conditions_skin: 0.512108674871367
# hs_health_conditions_cardiac: 0.5160879166717461
# hs_health_conditions_respiratory: 0.5259074983025489
# hs_health_conditions_gastrointestinal: 0.5171481388949103
# hs_health_conditions_liver: 0.5141220930662739
# hs_health_conditions_kidney: 0.619731859830238
# hs_health_conditions_reproductive: 0.5668829614328811
# hs_health_conditions_orthopedic: 0.4899045456854796
# hs_health_conditions_neurological: 0.5257811694600802
# hs_health_conditions_endocrine: 0.5139972573824281
# hs_health_conditions_hematologic: 0.46902689012730125
# hs_health_conditions_immune: 0.5092570909028021
# hs_health_conditions_infectious_disease: 0.5052255634079423
# hs_health_conditions_toxin_consumption: 0.4937228670443787
# hs_health_conditions_trauma: 0.5157246746249544
# hs_health_conditions_cancer: 0.5067568096243266
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7585056849310821]
# Fold Fold_2: [0.7586206869232756]
# Fold Fold_3: [0.758960060040409]
# Fold Fold_4: [0.7587629811401063]
# Fold Fold_5: [0.7586089131641913]
#
# Weighted Average AUC Score:
# 51.72%
# ===============================================
#
# ['feat_diet']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5546527230859049
# hs_health_conditions_ear: 0.5534928649559728
# hs_health_conditions_oral: 0.5451785231616093
# hs_health_conditions_skin: 0.5516993303502785
# hs_health_conditions_cardiac: 0.5670408626440073
# hs_health_conditions_respiratory: 0.5574588750265465
# hs_health_conditions_gastrointestinal: 0.5624527750554169
# hs_health_conditions_liver: 0.5957566566576252
# hs_health_conditions_kidney: 0.5610244619078006
# hs_health_conditions_reproductive: 0.57189777002341
# hs_health_conditions_orthopedic: 0.6224686846486522
# hs_health_conditions_neurological: 0.5808469927245904
# hs_health_conditions_endocrine: 0.5701640213782544
# hs_health_conditions_hematologic: 0.5894481293324072
# hs_health_conditions_immune: 0.5392773318454784
# hs_health_conditions_infectious_disease: 0.5347417491578845
# hs_health_conditions_toxin_consumption: 0.5043689983410069
# hs_health_conditions_trauma: 0.5447738194850839
# hs_health_conditions_cancer: 0.5722727055036108
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7633922447625812]
# Fold Fold_2: [0.7631840873318212]
# Fold Fold_3: [0.763807062770244]
# Fold Fold_4: [0.7637064773041818]
# Fold Fold_5: [0.7648666059800036]
#
# Weighted Average AUC Score:
# 56.21%
# ===============================================
#
# ['feat_hot_month']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5
# hs_health_conditions_ear: 0.5
# hs_health_conditions_oral: 0.5
# hs_health_conditions_skin: 0.5
# hs_health_conditions_cardiac: 0.5
# hs_health_conditions_respiratory: 0.5
# hs_health_conditions_gastrointestinal: 0.5
# hs_health_conditions_liver: 0.5
# hs_health_conditions_kidney: 0.5
# hs_health_conditions_reproductive: 0.5
# hs_health_conditions_orthopedic: 0.5
# hs_health_conditions_neurological: 0.5
# hs_health_conditions_endocrine: 0.5
# hs_health_conditions_hematologic: 0.5
# hs_health_conditions_immune: 0.5
# hs_health_conditions_infectious_disease: 0.5
# hs_health_conditions_toxin_consumption: 0.5
# hs_health_conditions_trauma: 0.5
# hs_health_conditions_cancer: 0.5
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7570548807153147]
# Fold Fold_2: [0.7570324520054494]
# Fold Fold_3: [0.7572107168325705]
# Fold Fold_4: [0.757082392623168]
# Fold Fold_5: [0.7569978282884828]
#
# Weighted Average AUC Score:
# 50.00%
# ===============================================
#
# ['feat_cold_month']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5
# hs_health_conditions_ear: 0.5
# hs_health_conditions_oral: 0.5
# hs_health_conditions_skin: 0.5
# hs_health_conditions_cardiac: 0.5
# hs_health_conditions_respiratory: 0.5
# hs_health_conditions_gastrointestinal: 0.5
# hs_health_conditions_liver: 0.5
# hs_health_conditions_kidney: 0.5
# hs_health_conditions_reproductive: 0.5
# hs_health_conditions_orthopedic: 0.5
# hs_health_conditions_neurological: 0.5
# hs_health_conditions_endocrine: 0.5
# hs_health_conditions_hematologic: 0.5
# hs_health_conditions_immune: 0.5
# hs_health_conditions_infectious_disease: 0.5
# hs_health_conditions_toxin_consumption: 0.5
# hs_health_conditions_trauma: 0.5
# hs_health_conditions_cancer: 0.5
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7570548807153147]
# Fold Fold_2: [0.7570324520054494]
# Fold Fold_3: [0.7572107168325705]
# Fold Fold_4: [0.757082392623168]
# Fold Fold_5: [0.7569978282884828]
#
# Weighted Average AUC Score:
# 50.00%
# ===============================================
#
# ['feat_pa_surface']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5183656020414196
# hs_health_conditions_ear: 0.5110295960318091
# hs_health_conditions_oral: 0.5407975683169564
# hs_health_conditions_skin: 0.521189197769064
# hs_health_conditions_cardiac: 0.5259487241760977
# hs_health_conditions_respiratory: 0.5075165190409952
# hs_health_conditions_gastrointestinal: 0.5302371813998932
# hs_health_conditions_liver: 0.521184989352703
# hs_health_conditions_kidney: 0.5129812440008752
# hs_health_conditions_reproductive: 0.5165191549407272
# hs_health_conditions_orthopedic: 0.514635845092233
# hs_health_conditions_neurological: 0.5194781095896148
# hs_health_conditions_endocrine: 0.5365995946973074
# hs_health_conditions_hematologic: 0.5129920756735202
# hs_health_conditions_immune: 0.5185327874022116
# hs_health_conditions_infectious_disease: 0.5197579288668803
# hs_health_conditions_toxin_consumption: 0.5161691786288747
# hs_health_conditions_trauma: 0.5266058847777927
# hs_health_conditions_cancer: 0.5171002747178831
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7589866870413566]
# Fold Fold_2: [0.7600603457671471]
# Fold Fold_3: [0.7592529416269745]
# Fold Fold_4: [0.7597340599427933]
# Fold Fold_5: [0.7594752999723674]
#
# Weighted Average AUC Score:
# 52.04%
# ===============================================
#
# ['feat_pa_total_hours']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5
# hs_health_conditions_ear: 0.5
# hs_health_conditions_oral: 0.5
# hs_health_conditions_skin: 0.5
# hs_health_conditions_cardiac: 0.5
# hs_health_conditions_respiratory: 0.5
# hs_health_conditions_gastrointestinal: 0.5
# hs_health_conditions_liver: 0.5
# hs_health_conditions_kidney: 0.5
# hs_health_conditions_reproductive: 0.5
# hs_health_conditions_orthopedic: 0.5
# hs_health_conditions_neurological: 0.5
# hs_health_conditions_endocrine: 0.5
# hs_health_conditions_hematologic: 0.5
# hs_health_conditions_immune: 0.5
# hs_health_conditions_infectious_disease: 0.5
# hs_health_conditions_toxin_consumption: 0.5
# hs_health_conditions_trauma: 0.5
# hs_health_conditions_cancer: 0.5
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7570548807153147]
# Fold Fold_2: [0.7570324520054494]
# Fold Fold_3: [0.7572107168325705]
# Fold Fold_4: [0.757082392623168]
# Fold Fold_5: [0.7569978282884828]
#
# Weighted Average AUC Score:
# 50.00%
# ===============================================
#
# ['feat_pa_wheather']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.554327144320322
# hs_health_conditions_ear: 0.5451163134274902
# hs_health_conditions_oral: 0.5671094200468689
# hs_health_conditions_skin: 0.5286446906653937
# hs_health_conditions_cardiac: 0.5709203731404378
# hs_health_conditions_respiratory: 0.5548752866710792
# hs_health_conditions_gastrointestinal: 0.5270100861914343
# hs_health_conditions_liver: 0.546245375481524
# hs_health_conditions_kidney: 0.5435314335167272
# hs_health_conditions_reproductive: 0.4789713079848393
# hs_health_conditions_orthopedic: 0.5420577367422051
# hs_health_conditions_neurological: 0.5605488652362073
# hs_health_conditions_endocrine: 0.5348334584998883
# hs_health_conditions_hematologic: 0.5107608924022377
# hs_health_conditions_immune: 0.4679120175039788
# hs_health_conditions_infectious_disease: 0.5055646928204871
# hs_health_conditions_toxin_consumption: 0.512379755931273
# hs_health_conditions_trauma: 0.5169530283789888
# hs_health_conditions_cancer: 0.5305487375737942
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7595661008827597]
# Fold Fold_2: [0.7604647616602516]
# Fold Fold_3: [0.7604774813620003]
# Fold Fold_4: [0.7595556327848617]
# Fold Fold_5: [0.7599039198294605]
#
# Weighted Average AUC Score:
# 53.15%
# ===============================================
#
# ['feat_od_income']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5
# hs_health_conditions_ear: 0.5
# hs_health_conditions_oral: 0.5
# hs_health_conditions_skin: 0.5
# hs_health_conditions_cardiac: 0.5
# hs_health_conditions_respiratory: 0.5
# hs_health_conditions_gastrointestinal: 0.5
# hs_health_conditions_liver: 0.5
# hs_health_conditions_kidney: 0.5
# hs_health_conditions_reproductive: 0.5
# hs_health_conditions_orthopedic: 0.5
# hs_health_conditions_neurological: 0.5
# hs_health_conditions_endocrine: 0.5
# hs_health_conditions_hematologic: 0.5
# hs_health_conditions_immune: 0.5
# hs_health_conditions_infectious_disease: 0.5
# hs_health_conditions_toxin_consumption: 0.5
# hs_health_conditions_trauma: 0.5
# hs_health_conditions_cancer: 0.5
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7578896362212301]
# Fold Fold_2: [0.7579625437763982]
# Fold Fold_3: [0.7577949005347294]
# Fold Fold_4: [0.7579043897379388]
# Fold Fold_5: [0.7578842327066073]
#
# Weighted Average AUC Score:
# 50.00%
# ===============================================
#
# ['feat_prim_census_division']
#
#  Average AUC Score per condition:
# hs_health_conditions_eye: 0.5145375869808494
# hs_health_conditions_ear: 0.5155158790348942
# hs_health_conditions_oral: 0.5238957533507917
# hs_health_conditions_skin: 0.535511887990056
# hs_health_conditions_cardiac: 0.5335146786831064
# hs_health_conditions_respiratory: 0.5077326701853154
# hs_health_conditions_gastrointestinal: 0.5052181691620847
# hs_health_conditions_liver: 0.5206468187434892
# hs_health_conditions_kidney: 0.5128931220457702
# hs_health_conditions_reproductive: 0.5251178890802699
# hs_health_conditions_orthopedic: 0.5137430731795005
# hs_health_conditions_neurological: 0.48897368774695815
# hs_health_conditions_endocrine: 0.5153829751676448
# hs_health_conditions_hematologic: 0.5055343611262831
# hs_health_conditions_immune: 0.5146493422132392
# hs_health_conditions_infectious_disease: 0.5506734150717973
# hs_health_conditions_toxin_consumption: 0.533586061524706
# hs_health_conditions_trauma: 0.5306372322545139
# hs_health_conditions_cancer: 0.5005150369495492
#
# Average AUC Scores per Fold:
# Fold Fold_1: [0.7595122805283119]
# Fold Fold_2: [0.7604439483708623]
# Fold Fold_3: [0.7600275866716719]
# Fold Fold_4: [0.7601638182282878]
# Fold Fold_5: [0.7600286403497232]
#
# Weighted Average AUC Score:
# 51.83%
# ===============================================
#
#
# Overall Average AUC Scores saved to overall_average_auc_results.csv

# %%
for i, features in enumerate(features_list):
    # Extract feature names from variable names in the features_list
    feature_names = [var_name for var_name, var_value in locals().items() if var_value is features and var_name.startswith('feat_')]

    print(feature_names)
# Out:
# ['feat_breed_top50_v2']
# ['feat_breed_group']
# ['feat_sub_breed']
# ['feat_breed_type']
# ['feat_breed_pure_or_mix']
# ['feat_age']
# ['feat_sex']
# ['feat_diet']
# ['feat_hot_month']
# ['feat_cold_month']
# ['feat_pa_surface']
# ['feat_pa_total_hours']
# ['feat_pa_wheather']
# ['feat_od_income']
# ['feat_prim_census_division']
