# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from helper import *
from sklearn.preprocessing import MultiLabelBinarizer
from ast import literal_eval

# %%
file_path_HLES = '../Dataset/SurveyData/SurveyData_CSV_DAP_2021_HLES_dog_owner_v1.0.csv'
df_HLES = pd.read_csv(file_path_HLES)
df_HLES
# Out:
# /var/folders/zd/3_6frj8s08b9zb1f3y0xqr2r0000gn/T/ipykernel_7090/1766648619.py:2: DtypeWarning: Columns (5,21,75,77,79,81,83,85,87,89,191,192,193,194,195,196,197,198,199,200,201,204,214,285,295,516,566) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_HLES = pd.read_csv(file_path_HLES)
#        dog_id  owner_id st_hles_completion_date  dd_breed_pure_or_mixed  \
# 0       10509     14660              2020-10-17                       2
# 1       74227     16755              2020-10-26                       2
# 2       32487      8568              2020-09-07                       1
# 3       63150      5380              2020-08-21                       2
# 4       33369     15957              2020-10-23                       2
# ...       ...       ...                     ...                     ...
# 33167   91849     32736              2021-06-22                       2
# 33168   33783      9482              2020-09-15                       2
# ...

# %%
file_path = '../Dataset/DogOverview/DogOverview_CSV_DAP_2021_DogOverview_v1.0.csv'
df_DO = pd.read_csv(file_path)
df_DO
# Out:
#        dog_id DAP_Pack_Date    Cohort Cohort_Enroll_Date Estimated_DOB  \
# 0           8    2020-08-12  DAP Pack                NaN    2011-02-15
# 1           9    2020-10-28  DAP Pack                NaN    2008-04-15
# 2          11    2020-08-31  DAP Pack                NaN    2011-04-15
# 3          12    2020-09-15  DAP Pack                NaN    2013-08-15
# 4          13    2020-11-22  DAP Pack                NaN    2018-03-15
# ...       ...           ...       ...                ...           ...
# 33167  103633    2021-12-29  DAP Pack                NaN    2014-09-15
# 33168  103637    2021-12-29  DAP Pack                NaN    2019-12-15
# 33169  103643    2021-12-30  DAP Pack                NaN    2020-04-15
# 33170  103647    2021-12-31  DAP Pack                NaN    2016-08-15
# 33171  103658    2021-12-31  DAP Pack                NaN    2010-12-31
#
#        Estimated_Age_Years_at_HLES  \
# 0                              9.5
# 1                             12.5
# ...

# %%
df_HLES['dd_weight_lbs'].value_counts()
# Out:
# dd_weight_lbs
# 65.00     849
# 55.00     763
# 75.00     615
# 45.00     570
# 62.00     542
#          ...
# 18.75       1
# 21.63       1
# 92.60       1
# 104.50      1
# 106.60      1
# Name: count, Length: 1140, dtype: int64

# %%
id_weight = df_HLES[['dog_id', 'dd_weight_lbs']]
id_weight
# Out:
#        dog_id  dd_weight_lbs
# 0       10509           33.0
# 1       74227           44.0
# 2       32487           20.0
# 3       63150           65.0
# 4       33369           34.8
# ...       ...            ...
# 33167   91849           19.2
# 33168   33783           15.0
# 33169   98862           62.0
# 33170   99462           15.0
# 33171    6530           51.0
#
# [33172 rows x 2 columns]

# %%
id_weight.to_pickle('features/weight.pkl')
id_weight.to_csv('features/weight.csv', index=False)
